# %%
import sys
sys.path.append(r"C:\Users\Fonta\IdeaProjects\ATI_Analysis")
sys.path.append(r"C:\Users\913678186\IdeaProjects\ATI_Analysis")
from app.database.queries.implementation.create import add_guidance
###
### ADD Guidance
###

import ipywidgets as widgets
from IPython.display import display
from datetime import datetime



# Create form widgets for adding a Guideline
guideline_title = widgets.Text(value='', placeholder='Enter guideline title', description='Title:', disabled=False)
guideline_description = widgets.Textarea(value='', placeholder='Enter guidance description', description='Description:', disabled=False)
submit_button = widgets.Button(description='Submit', disabled=False, button_style='', tooltip='Click to submit', icon='check')
output = widgets.Output()

# Define the event handler for the submit button
def on_button_click(b):
    with output:
        output.clear_output()
        success = add_guidance(
            title=guideline_title.value,
            description=guideline_description.value,
        )
        if success:
            print('Guidance added successfully')
        else:
            print('Guidance to add guideline')

# Attach the event handler to the button
submit_button.on_click(on_button_click)

# Display the form
form_items = [guideline_title, guideline_description, submit_button, output]
form = widgets.VBox(form_items)
display(form)

# %%
import sys
sys.path.append(r"C:\Users\Fonta\IdeaProjects\ATI_Analysis")
sys.path.append(r"C:\Users\913678186\IdeaProjects\ATI_Analysis")
from app.database.queries.implementation.create import add_process
###
### ADD PROCESS

import ipywidgets as widgets
from IPython.display import display

from datetime import datetime

# Create form widgets for adding a Process
process_title = widgets.Text(value='', placeholder='Enter process title', description='Title:', disabled=False)
process_description = widgets.Textarea(value='', placeholder='Enter process description', description='Description:', disabled=False)
submit_button = widgets.Button(description='Submit', disabled=False, button_style='', tooltip='Click to submit', icon='check')
output = widgets.Output()

# Define the event handler for the submit button
def on_button_click(b):
    with output:
        output.clear_output()
        success = add_process(
            title=process_title.value,
            description=process_description.value
        )
        if success:
            print('Process added successfully')
        else:
            print('Failed to add process')

# Attach the event handler to the bu
submit_button.on_click(on_button_click)

# Display the form
form_items = [process_title, process_description, submit_button, output]
form = widgets.VBox(form_items)
display(form)

# %%
##
## Add Project
##


from app.database.queries.implementation.create import add_project
import ipywidgets as widgets
from IPython.display import display

from datetime import datetime

# Create form widgets for adding a Project
project_title = widgets.Text(value='', placeholder='Enter project title', description='Title:', disabled=False)
project_description = widgets.Textarea(value='', placeholder='Enter project description', description='Description:', disabled=False)
submit_button = widgets.Button(description='Submit', disabled=False, button_style='', tooltip='Click to submit', icon='check')
output = widgets.Output()

# Define the event handler for the submit button
def on_button_click(b):
    with output:
        output.clear_output()
        success = add_project(
            title=project_title.value,
            description=project_description.value
        )
        if success:
            print('Project added successfully')
        else:
            print('Failed to add project')

# Attach the event handler to the button
submit_button.on_click(on_button_click)

# Display the form
form_items = [project_title, project_description, submit_button, output]
form = widgets.VBox(form_items)
display(form)

# %%
##
## Add Procedure
##
import sys
sys.path.append(r"C:\Users\Fonta\IdeaProjects\ATI_Analysis")
sys.path.append(r"C:\Users\913678186\IdeaProjects\ATI_Analysis")
from app.database.graph_schema import set_connection
from app.database.queries.implementation.create import add_procedure
import ipywidgets as widgets
from IPython.display import display

from datetime import datetime
set_connection()

# Create form widgets for adding a Procedure
procedure_title = widgets.Text(value='', placeholder='Enter procedure title', description='Title:', disabled=False)
procedure_description = widgets.Textarea(value='', placeholder='Enter procedure description', description='Description:', disabled=False)
submit_button = widgets.Button(description='Submit', disabled=False, button_style='', tooltip='Click to submit', icon='check')
output = widgets.Output()

# Define the event handler for the submit button
def on_button_click(b):
    with output:
        output.clear_output()
        success = add_procedure(
            title=procedure_title.value,
            description=procedure_description.value
        )
        if success:
            print('Procedure added successfully')
        else:
            print('Failed to add procedure')

# Attach the event handler to the button
submit_button.on_click(on_button_click)

# Display the form
form_items = [procedure_title, procedure_description, submit_button, output]
form = widgets.VBox(form_items)
display(form)
# Out:
# None
# None
# None
# C:\Users\Fonta\IdeaProjects\ATI_Analysis\app
# bolt://neo4j:accessibility@130.212.104.18:7687
# bolt://neo4j:accessibility@130.212.104.18:7687
# ...

# %%
##
## Add Service
##

from app.database.queries.implementation.create import add_service
import ipywidgets as widgets
from IPython.display import display

from datetime import datetime

# Create form widgets for adding a Service
service_title = widgets.Text(value='', placeholder='Enter service title', description='Title:', disabled=False)
service_description = widgets.Textarea(value='', placeholder='Enter service description', description='Description:', disabled=False)
submit_button = widgets.Button(description='Submit', disabled=False, button_style='', tooltip='Click to submit', icon='check')
output = widgets.Output()

# Define the event handler for the submit button
def on_button_click(b):
    with output:
        output.clear_output()
        success = add_service(
            title=service_title.value,
            description=service_description.value
        )
        if success:
            print('Service added successfully')
        else:
            print('Failed to add service')

# Attach the event handler to the button
submit_button.on_click(on_button_click)

# Display the form
form_items = [service_title, service_description, submit_button, output]
form = widgets.VBox(form_items)
display(form)

# %%
##
## Add Plan
##

import sys
sys.path.append(r"C:\Users\Fonta\IdeaProjects\ATI_Analysis")
sys.path.append(r"C:\Users\913678186\IdeaProjects\ATI_Analysis")

from app.database.queries.implementation.create import add_plan
import ipywidgets as widgets
from IPython.display import display

from datetime import datetime

# Create form widgets for adding a Plan
plan_title = widgets.Text(value='', placeholder='Enter plan title', description='Title:', disabled=False)
plan_description = widgets.Textarea(value='', placeholder='Enter plan description', description='Description:', disabled=False)
is_campus_plan = widgets.Checkbox(value=False, description='Is Campus Plan')
submit_button = widgets.Button(description='Submit', disabled=False, button_style='', tooltip='Click to submit', icon='check')
output = widgets.Output()

# Define the event handler for the submit button
def on_button_click(b):
    with output:
        output.clear_output()
        success = add_plan(
            title=plan_title.value,
            description=plan_description.value,
            is_campus_plan=is_campus_plan.value
        )
        if success:
            print('Plan added successfully')
        else:
            print('Failed to add plan')

# Attach the event handler to the button
submit_button.on_click(on_button_click)

# Display the form
form_items = [plan_title, plan_description, is_campus_plan, submit_button, output]
form = widgets.VBox(form_items)
display(form)

# %%
#
# Add Tracking
#
import sys
sys.path.append(r"C:\Users\Fonta\IdeaProjects\ATI_Analysis")

import ipywidgets as widgets
from IPython.display import display
from app.database.queries.implementation.create import add_tracking

# Create form widgets for adding tracking
tracking_title = widgets.Text(value='', placeholder='Enter tracking title', description='Title:', disabled=False)
tracking_description = widgets.Textarea(value='', placeholder='Enter description', description='Description:', disabled=False)
submit_button = widgets.Button(description='Submit', disabled=False, button_style='', tooltip='Click to submit', icon='check')
output = widgets.Output()

# Define the event handler for the submit button
def on_button_click(b):
    with output:
        output.clear_output()
        success = add_tracking(
            title=tracking_title.value,
            description=tracking_description.value
        )
        if success:
            print('Tracking added successfully')
        else:
            print('Failed to add tracking')

# Attach the event handler to the button
submit_button.on_click(on_button_click)

# Display the form
form_items = [tracking_title, tracking_description, submit_button, output]
form = widgets.VBox(form_items)
display(form)

# %%
#
# Add InternalPolicy
#

import sys
sys.path.append(r"C:\Users\Fonta\IdeaProjects\ATI_Analysis")

from app.database.queries.implementation.create import add_internal_policy
import ipywidgets as widgets
from IPython.display import display

# Create form widgets for adding an InternalPolicy
policy_title = widgets.Text(value='', placeholder='Enter policy title', description='Title:', disabled=False)
policy_description = widgets.Textarea(value='', placeholder='Enter policy description', description='Description:', disabled=False)
submit_button = widgets.Button(description='Submit', disabled=False, button_style='', tooltip='Click to submit', icon='check')
output = widgets.Output()

# Define the event handler for the submit button
def on_button_click(b):
    with output:
        output.clear_output()
        success = add_internal_policy(
            title=policy_title.value,
            description=policy_description.value
        )
        if success:
            print('InternalPolicy added successfully')
        else:
            print('Failed to add InternalPolicy')

# Attach the event handler to the button
submit_button.on_click(on_button_click)

# Display the form
form_items = [policy_title, policy_description, submit_button, output]
form = widgets.VBox(form_items)
display(form)
